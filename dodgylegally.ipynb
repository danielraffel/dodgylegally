# %% [markdown]
# <a href="https://colab.research.google.com/github/danielraffel/dodgylegally/blob/main/dodgylegally.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# script hacked together by Daniel Raffel based on original work here https://x.com/ColugoMusic/status/1726001266180956440?s=20

# Install the required packages
# !pip install pydub yt-dlp glob2 nltk

# Import necessary libraries
from google.colab import drive
import os
import nltk
from pydub import AudioSegment
import random

# Connect to Google Drive
drive.mount('/content/drive')

# Base directory in Google Drive (modify this path as needed)
base_dir = '/content/drive/My Drive/dodgylegally'

# Check if base directory exists, if not, create it
if not os.path.exists(base_dir):
    os.makedirs(base_dir)

# Change to your project directory in Google Drive
os.chdir(base_dir)

# Paths for the folders
loop_dir = os.path.join(base_dir, 'wavs/processed/loop')
oneshot_dir = os.path.join(base_dir, 'wavs/processed/oneshot')
raw_dir = os.path.join(base_dir, 'wavs/raw')

# Create the required folders if they don't exist
os.makedirs(loop_dir, exist_ok=True)
os.makedirs(oneshot_dir, exist_ok=True)
os.makedirs(raw_dir, exist_ok=True)

# Check if 'birdwater.txt' exists, if not create it and populate with random words
word_list_file = os.path.join(base_dir, 'birdwater.txt')
if not os.path.exists(word_list_file):
    nltk.download('words')
    from nltk.corpus import words
    word_list = random.sample(words.words(), 200)
    with open(word_list_file, 'w') as file:
        for word in word_list:
            file.write(word + '\n')

# ColugoMusic script with a slight modification for BATCH_SIZE
from pydub import AudioSegment, effects
from yt_dlp import YoutubeDL
import glob
import random

# Modify BATCH_SIZE based on user input
BATCH_SIZE = int(input("Enter the number of samples (default 10): ") or "10")
MAX_SEARCH_RESULTS = 10
DOWNLOAD_DIR = 'wavs/raw'
LOOP_OUTPUT_DIR = 'wavs/processed/loop'
ONESHOT_OUTPUT_DIR = 'wavs/processed/oneshot'
WORD_LIST = 'birdwater.txt'

def read_lines(file):
  return open(file).read().splitlines()

class download_range_func:
  def __init__(self):
    pass
  def __call__(self, info_dict, ydl):
    timestamp = self.make_timestamp(info_dict)
    yield {
        'start_time': timestamp,
        'end_time': timestamp,
    }
  @staticmethod
  def make_timestamp(info):
      duration = info['duration']
      if duration is None:
        return 0
      return duration/2

def make_random_search_phrase(word_list):
  words = random.sample(word_list, 2)
  phrase = ' '.join(words)
  print('Search phrase: "{}"'.format(phrase))
  return phrase

def make_download_options(phrase):
  safe_phrase = ''.join(x for x in phrase if x.isalnum() or x in "._- ")
  return {
    'format': 'bestaudio/best',
    'paths': {'home': DOWNLOAD_DIR},
    'outtmpl': {'default': f'{safe_phrase}-%(id)s.%(ext)s'},
    'download_ranges': download_range_func(),
    'postprocessors': [{
        'key': 'FFmpegExtractAudio',
        'preferredcodec': 'wav',
    }]
  }

def make_oneshot(sound, phrase, output_filepath):
  final_length = min(2000, len(sound))
  quarter = int(final_length/4)
  sound   = sound[:final_length]
  sound   = sound.fade_out(duration=quarter)
  sound   = effects.normalize(sound)
  sound.export(output_filepath, format="wav")

def make_loop(sound, phrase, output_filepath):
    final_length = min(2000, len(sound))
    half         = int(final_length/2)
    fade_length  = int(final_length/4)
    beg   = sound[:half]
    end   = sound[half:]
    end   = end[:fade_length]
    beg   = beg.fade_in(duration=fade_length)
    end   = end.fade_out(duration=fade_length)
    sound = beg.overlay(end)
    sound = effects.normalize(sound)
    sound.export(output_filepath, format="wav")

def process_file(filepath, phrase):
  try:
    safe_phrase = ''.join(x for x in phrase if x.isalnum() or x in "._- ")
    filename                 = os.path.basename(filepath)
    output_filepath_oneshot  = os.path.join(ONESHOT_OUTPUT_DIR, f'oneshot_{safe_phrase}-{filename}')
    output_filepath_loop     = os.path.join(LOOP_OUTPUT_DIR, f'loop_{safe_phrase}-{filename}')

    sound = AudioSegment.from_file(filepath, "wav")
    if (len(sound) > 500):
      if not os.path.exists(output_filepath_oneshot):
        make_oneshot(sound, phrase, output_filepath_oneshot)
      if not os.path.exists(output_filepath_loop):
        make_loop(sound, phrase, output_filepath_loop)
    os.remove(filepath)
  except Exception as err:
    print("Failed to process '{}' ({})".format(filepath, err))

def create_combined_loop():
    combined_dir = os.path.join(base_dir, 'wavs/processed/combined')
    os.makedirs(combined_dir, exist_ok=True)  # Create the combined directory if it doesn't exist

    combined_loop = AudioSegment.silent(duration=100)  # A short silence to start
    for filepath in glob.glob(os.path.join(LOOP_OUTPUT_DIR, '*.wav')):
        sound = AudioSegment.from_file(filepath, format="wav")
        repeated_sound = sound * random.randint(3, 4)  # Repeat 3 or 4 times
        combined_loop += repeated_sound

    version = 1
    output_filename = "combined_loop_v{}.wav".format(version)
    output_filepath = os.path.join(combined_dir, output_filename)

    # Check if file already exists, and increment version number if it does
    while os.path.exists(output_filepath):
        version += 1
        output_filename = "combined_loop_v{}.wav".format(version)
        output_filepath = os.path.join(combined_dir, output_filename)

    combined_loop.export(output_filepath, format="wav")

def setup():
    if not os.path.exists(LOOP_OUTPUT_DIR):
      os.makedirs(LOOP_OUTPUT_DIR)
    if not os.path.exists(ONESHOT_OUTPUT_DIR):
      os.makedirs(ONESHOT_OUTPUT_DIR)

def main():
    try:
        setup()
        word_list = read_lines(WORD_LIST)
        for _ in range(BATCH_SIZE):
            phrase    = make_random_search_phrase(word_list)
            video_url = f'ytsearch1:"{phrase}"'
            options   = make_download_options(phrase)
            YoutubeDL(options).download([video_url])
            for filepath in glob.glob(os.path.join(DOWNLOAD_DIR, f'{phrase}-*.wav')):
                process_file(filepath, phrase)

        create_combined_loop()  # Call this function to create the combined loop

    except Exception as err:
        print('FATAL ERROR: {}'.format(err))

# Run the main function
if __name__ == '__main__':
    main()
# Out:
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: yt-dlp in /usr/local/lib/python3.10/dist-packages (2023.11.16)
# Requirement already satisfied: glob2 in /usr/local/lib/python3.10/dist-packages (0.7)
# Requirement already satisfied: nltk in /usr/local/lib/python3.10/dist-packages (3.8.1)
# Requirement already satisfied: mutagen in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.47.0)
# Requirement already satisfied: pycryptodomex in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (3.19.0)
# Requirement already satisfied: websockets in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (12.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2023.7.22)
# Requirement already satisfied: requests<3,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.26.17 in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (2.0.7)
# Requirement already satisfied: brotli in /usr/local/lib/python3.10/dist-packages (from yt-dlp) (1.1.0)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk) (2023.6.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from nltk) (4.66.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.31.0->yt-dlp) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2.31.0->yt-dlp) (3.4)
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Enter the number of samples (default 10): 20
# Search phrase: "Vermiformia woman"
# [youtube:search] Extracting URL: ytsearch1:"Vermiformia woman"
# [download] Downloading playlist: "Vermiformia woman"
# [youtube:search] query ""Vermiformia woman"": Downloading web client config
# [youtube:search] query ""Vermiformia woman"" page 1: Downloading API JSON
# [youtube:search] Playlist "Vermiformia woman": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=LSeASpvgmwE
# [youtube] LSeASpvgmwE: Downloading webpage
# [youtube] LSeASpvgmwE: Downloading ios player API JSON
# [youtube] LSeASpvgmwE: Downloading android player API JSON
# [youtube] LSeASpvgmwE: Downloading m3u8 information
# [info] LSeASpvgmwE: Downloading 1 format(s): 251
# [info] LSeASpvgmwE: Downloading 1 time ranges: 749.5-749.5
# [download] Destination: wavs/raw/Vermiformia woman-LSeASpvgmwE.webm
# [download] 100% of  150.19KiB in 00:00:06 at 24.79KiB/s
# [ExtractAudio] Destination: wavs/raw/Vermiformia woman-LSeASpvgmwE.wav
# Deleting original file wavs/raw/Vermiformia woman-LSeASpvgmwE.webm (pass -k to keep)
# [download] Finished downloading playlist: "Vermiformia woman"
# Search phrase: "inapperceptible suspirative"
# [youtube:search] Extracting URL: ytsearch1:"inapperceptible suspirative"
# [download] Downloading playlist: "inapperceptible suspirative"
# [youtube:search] query ""inapperceptible suspirative"": Downloading web client config
# [youtube:search] query ""inapperceptible suspirative"" page 1: Downloading API JSON
# [youtube:search] Playlist "inapperceptible suspirative": Downloading 0 items
# [download] Finished downloading playlist: "inapperceptible suspirative"
# Search phrase: "tropeine vowelization"
# [youtube:search] Extracting URL: ytsearch1:"tropeine vowelization"
# [download] Downloading playlist: "tropeine vowelization"
# [youtube:search] query ""tropeine vowelization"": Downloading web client config
# [youtube:search] query ""tropeine vowelization"" page 1: Downloading API JSON
# [youtube:search] Playlist "tropeine vowelization": Downloading 0 items
# [download] Finished downloading playlist: "tropeine vowelization"
# Search phrase: "equipollency vowelization"
# [youtube:search] Extracting URL: ytsearch1:"equipollency vowelization"
# [download] Downloading playlist: "equipollency vowelization"
# [youtube:search] query ""equipollency vowelization"": Downloading web client config
# [youtube:search] query ""equipollency vowelization"" page 1: Downloading API JSON
# [youtube:search] Playlist "equipollency vowelization": Downloading 0 items
# [download] Finished downloading playlist: "equipollency vowelization"
# Search phrase: "nandi roll"
# [youtube:search] Extracting URL: ytsearch1:"nandi roll"
# [download] Downloading playlist: "nandi roll"
# [youtube:search] query ""nandi roll"": Downloading web client config
# [youtube:search] query ""nandi roll"" page 1: Downloading API JSON
# [youtube:search] Playlist "nandi roll": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=VsvAMcwSpxQ
# [youtube] VsvAMcwSpxQ: Downloading webpage
# [youtube] VsvAMcwSpxQ: Downloading ios player API JSON
# [youtube] VsvAMcwSpxQ: Downloading android player API JSON
# [youtube] VsvAMcwSpxQ: Downloading m3u8 information
# [info] VsvAMcwSpxQ: Downloading 1 format(s): 251
# [info] VsvAMcwSpxQ: Downloading 1 time ranges: 32.5-32.5
# [download] Destination: wavs/raw/nandi roll-VsvAMcwSpxQ.webm
# [download] 100% of   29.49KiB in 00:00:01 at 24.44KiB/s
# [ExtractAudio] Destination: wavs/raw/nandi roll-VsvAMcwSpxQ.wav
# Deleting original file wavs/raw/nandi roll-VsvAMcwSpxQ.webm (pass -k to keep)
# [download] Finished downloading playlist: "nandi roll"
# Search phrase: "Lachnanthes oligotrophic"
# [youtube:search] Extracting URL: ytsearch1:"Lachnanthes oligotrophic"
# [download] Downloading playlist: "Lachnanthes oligotrophic"
# [youtube:search] query ""Lachnanthes oligotrophic"": Downloading web client config
# [youtube:search] query ""Lachnanthes oligotrophic"" page 1: Downloading API JSON
# [youtube:search] Playlist "Lachnanthes oligotrophic": Downloading 0 items
# [download] Finished downloading playlist: "Lachnanthes oligotrophic"
# Search phrase: "obmutescence parotitic"
# [youtube:search] Extracting URL: ytsearch1:"obmutescence parotitic"
# [download] Downloading playlist: "obmutescence parotitic"
# [youtube:search] query ""obmutescence parotitic"": Downloading web client config
# [youtube:search] query ""obmutescence parotitic"" page 1: Downloading API JSON
# [youtube:search] Playlist "obmutescence parotitic": Downloading 0 items
# [download] Finished downloading playlist: "obmutescence parotitic"
# Search phrase: "tropeine quinonize"
# [youtube:search] Extracting URL: ytsearch1:"tropeine quinonize"
# [download] Downloading playlist: "tropeine quinonize"
# [youtube:search] query ""tropeine quinonize"": Downloading web client config
# [youtube:search] query ""tropeine quinonize"" page 1: Downloading API JSON
# [youtube:search] Playlist "tropeine quinonize": Downloading 0 items
# [download] Finished downloading playlist: "tropeine quinonize"
# Search phrase: "unricht tipping"
# [youtube:search] Extracting URL: ytsearch1:"unricht tipping"
# [download] Downloading playlist: "unricht tipping"
# [youtube:search] query ""unricht tipping"": Downloading web client config
# [youtube:search] query ""unricht tipping"" page 1: Downloading API JSON
# [youtube:search] Playlist "unricht tipping": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dk2m_jgVZtw
# [youtube] dk2m_jgVZtw: Downloading webpage
# [youtube] dk2m_jgVZtw: Downloading ios player API JSON
# [youtube] dk2m_jgVZtw: Downloading android player API JSON
# [youtube] dk2m_jgVZtw: Downloading m3u8 information
# [info] dk2m_jgVZtw: Downloading 1 format(s): 251
# [info] dk2m_jgVZtw: Downloading 1 time ranges: 1199.0-1199.0
# [download] Destination: wavs/raw/unricht tipping-dk2m_jgVZtw.webm
# [download] 100% of  144.79KiB in 00:00:06 at 22.99KiB/s
# [ExtractAudio] Destination: wavs/raw/unricht tipping-dk2m_jgVZtw.wav
# Deleting original file wavs/raw/unricht tipping-dk2m_jgVZtw.webm (pass -k to keep)
# [download] Finished downloading playlist: "unricht tipping"
# Search phrase: "razorbill Kiwanis"
# [youtube:search] Extracting URL: ytsearch1:"razorbill Kiwanis"
# [download] Downloading playlist: "razorbill Kiwanis"
# [youtube:search] query ""razorbill Kiwanis"": Downloading web client config
# [youtube:search] query ""razorbill Kiwanis"" page 1: Downloading API JSON
# [youtube:search] Playlist "razorbill Kiwanis": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=4HCtZ2-n5yI
# [youtube] 4HCtZ2-n5yI: Downloading webpage
# [youtube] 4HCtZ2-n5yI: Downloading ios player API JSON
# [youtube] 4HCtZ2-n5yI: Downloading android player API JSON
# [youtube] 4HCtZ2-n5yI: Downloading m3u8 information
# [info] 4HCtZ2-n5yI: Downloading 1 format(s): 251
# [info] 4HCtZ2-n5yI: Downloading 1 time ranges: 1716.5-1716.5
# [download] Destination: wavs/raw/razorbill Kiwanis-4HCtZ2-n5yI.webm
# [download] 100% of   83.76KiB in 00:00:04 at 19.45KiB/s
# [ExtractAudio] Destination: wavs/raw/razorbill Kiwanis-4HCtZ2-n5yI.wav
# Deleting original file wavs/raw/razorbill Kiwanis-4HCtZ2-n5yI.webm (pass -k to keep)
# [download] Finished downloading playlist: "razorbill Kiwanis"
# Search phrase: "protectingness convocationist"
# [youtube:search] Extracting URL: ytsearch1:"protectingness convocationist"
# [download] Downloading playlist: "protectingness convocationist"
# [youtube:search] query ""protectingness convocationist"": Downloading web client config
# [youtube:search] query ""protectingness convocationist"" page 1: Downloading API JSON
# [youtube:search] Playlist "protectingness convocationist": Downloading 0 items
# [download] Finished downloading playlist: "protectingness convocationist"
# Search phrase: "multivious venally"
# [youtube:search] Extracting URL: ytsearch1:"multivious venally"
# [download] Downloading playlist: "multivious venally"
# [youtube:search] query ""multivious venally"": Downloading web client config
# [youtube:search] query ""multivious venally"" page 1: Downloading API JSON
# [youtube:search] Playlist "multivious venally": Downloading 0 items
# [download] Finished downloading playlist: "multivious venally"
# Search phrase: "upwind razorbill"
# [youtube:search] Extracting URL: ytsearch1:"upwind razorbill"
# [download] Downloading playlist: "upwind razorbill"
# [youtube:search] query ""upwind razorbill"": Downloading web client config
# [youtube:search] query ""upwind razorbill"" page 1: Downloading API JSON
# [youtube:search] Playlist "upwind razorbill": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=fMnyD7QR43k
# [youtube] fMnyD7QR43k: Downloading webpage
# [youtube] fMnyD7QR43k: Downloading ios player API JSON
# [youtube] fMnyD7QR43k: Downloading android player API JSON
# [youtube] fMnyD7QR43k: Downloading m3u8 information
# [info] fMnyD7QR43k: Downloading 1 format(s): 251
# [info] fMnyD7QR43k: Downloading 1 time ranges: 8.5-8.5
# [download] Destination: wavs/raw/upwind razorbill-fMnyD7QR43k.webm
# [download] 100% of   95.88KiB in 00:00:00 at 123.17KiB/s
# [ExtractAudio] Destination: wavs/raw/upwind razorbill-fMnyD7QR43k.wav
# Deleting original file wavs/raw/upwind razorbill-fMnyD7QR43k.webm (pass -k to keep)
# [download] Finished downloading playlist: "upwind razorbill"
# Search phrase: "dorsum preservatize"
# [youtube:search] Extracting URL: ytsearch1:"dorsum preservatize"
# [download] Downloading playlist: "dorsum preservatize"
# [youtube:search] query ""dorsum preservatize"": Downloading web client config
# [youtube:search] query ""dorsum preservatize"" page 1: Downloading API JSON
# [youtube:search] Playlist "dorsum preservatize": Downloading 0 items
# [download] Finished downloading playlist: "dorsum preservatize"
# Search phrase: "parotitic casefy"
# [youtube:search] Extracting URL: ytsearch1:"parotitic casefy"
# [download] Downloading playlist: "parotitic casefy"
# [youtube:search] query ""parotitic casefy"": Downloading web client config
# [youtube:search] query ""parotitic casefy"" page 1: Downloading API JSON
# [youtube:search] Playlist "parotitic casefy": Downloading 0 items
# [download] Finished downloading playlist: "parotitic casefy"
# Search phrase: "rommack Richard"
# [youtube:search] Extracting URL: ytsearch1:"rommack Richard"
# [download] Downloading playlist: "rommack Richard"
# [youtube:search] query ""rommack Richard"": Downloading web client config
# [youtube:search] query ""rommack Richard"" page 1: Downloading API JSON
# [youtube:search] Playlist "rommack Richard": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=A0MYr3IqZAY
# [youtube] A0MYr3IqZAY: Downloading webpage
# [youtube] A0MYr3IqZAY: Downloading ios player API JSON
# [youtube] A0MYr3IqZAY: Downloading android player API JSON
# [youtube] A0MYr3IqZAY: Downloading m3u8 information
# [info] A0MYr3IqZAY: Downloading 1 format(s): 251
# [info] A0MYr3IqZAY: Downloading 1 time ranges: 328.5-328.5
# [download] Destination: wavs/raw/rommack Richard-A0MYr3IqZAY.webm
# [download] 100% of  118.38KiB in 00:00:00 at 243.11KiB/s
# [ExtractAudio] Destination: wavs/raw/rommack Richard-A0MYr3IqZAY.wav
# Deleting original file wavs/raw/rommack Richard-A0MYr3IqZAY.webm (pass -k to keep)
# [download] Finished downloading playlist: "rommack Richard"
# Search phrase: "unoverruled equerryship"
# [youtube:search] Extracting URL: ytsearch1:"unoverruled equerryship"
# [download] Downloading playlist: "unoverruled equerryship"
# [youtube:search] query ""unoverruled equerryship"": Downloading web client config
# [youtube:search] query ""unoverruled equerryship"" page 1: Downloading API JSON
# [youtube:search] Playlist "unoverruled equerryship": Downloading 0 items
# [download] Finished downloading playlist: "unoverruled equerryship"
# Search phrase: "iodizer tipping"
# [youtube:search] Extracting URL: ytsearch1:"iodizer tipping"
# [download] Downloading playlist: "iodizer tipping"
# [youtube:search] query ""iodizer tipping"": Downloading web client config
# [youtube:search] query ""iodizer tipping"" page 1: Downloading API JSON
# [youtube:search] Playlist "iodizer tipping": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=dOdK6HnYqGQ
# [youtube] dOdK6HnYqGQ: Downloading webpage
# [youtube] dOdK6HnYqGQ: Downloading ios player API JSON
# [youtube] dOdK6HnYqGQ: Downloading android player API JSON
# [youtube] dOdK6HnYqGQ: Downloading m3u8 information
# [info] dOdK6HnYqGQ: Downloading 1 format(s): 251
# [info] dOdK6HnYqGQ: Downloading 1 time ranges: 73.5-73.5
# [download] Destination: wavs/raw/iodizer tipping-dOdK6HnYqGQ.webm
# [download] 100% of   58.04KiB in 00:00:00 at 154.16KiB/s
# [ExtractAudio] Destination: wavs/raw/iodizer tipping-dOdK6HnYqGQ.wav
# Deleting original file wavs/raw/iodizer tipping-dOdK6HnYqGQ.webm (pass -k to keep)
# [download] Finished downloading playlist: "iodizer tipping"
# Search phrase: "pseudorheumatic warsaw"
# [youtube:search] Extracting URL: ytsearch1:"pseudorheumatic warsaw"
# [download] Downloading playlist: "pseudorheumatic warsaw"
# [youtube:search] query ""pseudorheumatic warsaw"": Downloading web client config
# [youtube:search] query ""pseudorheumatic warsaw"" page 1: Downloading API JSON
# [youtube:search] Playlist "pseudorheumatic warsaw": Downloading 0 items
# [download] Finished downloading playlist: "pseudorheumatic warsaw"
# Search phrase: "roll sizably"
# [youtube:search] Extracting URL: ytsearch1:"roll sizably"
# [download] Downloading playlist: "roll sizably"
# [youtube:search] query ""roll sizably"": Downloading web client config
# [youtube:search] query ""roll sizably"" page 1: Downloading API JSON
# [youtube:search] Playlist "roll sizably": Downloading 1 items of 1
# [download] Downloading item 1 of 1
# [youtube] Extracting URL: https://www.youtube.com/watch?v=98R3fgPKmYs
# [youtube] 98R3fgPKmYs: Downloading webpage
# [youtube] 98R3fgPKmYs: Downloading ios player API JSON
# [youtube] 98R3fgPKmYs: Downloading android player API JSON
# [youtube] 98R3fgPKmYs: Downloading m3u8 information
# [info] 98R3fgPKmYs: Downloading 1 format(s): 251
# [info] 98R3fgPKmYs: Downloading 1 time ranges: 374.0-374.0
# [download] Destination: wavs/raw/roll sizably-98R3fgPKmYs.webm
# [download] 100% of   65.83KiB in 00:00:00 at 93.90KiB/s
# [ExtractAudio] Destination: wavs/raw/roll sizably-98R3fgPKmYs.wav
# Deleting original file wavs/raw/roll sizably-98R3fgPKmYs.webm (pass -k to keep)
# [download] Finished downloading playlist: "roll sizably"
